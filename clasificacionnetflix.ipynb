# %% [markdown]
# import pandas as pd
# df=pd.read_ipynb("/content/an-lisis-exploratorio-en-netflix-con-python.ipynb")
# df

# %%
import pandas as pd

# Replace '/path/to/your/data.csv' with the actual path to your CSV file
try:
  df = pd.read_csv('/path/to/your/data.csv')
  print("DataFrame loaded successfully!")
  display(df.head())
except FileNotFoundError:
  print("Error: Make sure the file path is correct.")
except Exception as e:
  print(f"An error occurred: {e}")
# Out:
# Error: Make sure the file path is correct.
