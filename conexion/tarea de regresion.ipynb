# %%
import pandas as pd
x=[1,2,2,3,4,4,5,6]
y=[2,3,4,4,4,6,5,7]


dicc_datos= {"x":x,"y":y}
df=pd.DataFrame(dicc_datos) #convierte al diccionario en un dataframe(marco de datos o tabla o dataset)

df["xy"] = df["x"] * (df["y"])
df["x2"] = df["x"] **2


df
# Out:
#    x  y  xy  x2
# 0  1  2   2   1
# 1  2  3   6   4
# 2  2  4   8   4
# 3  3  4  12   9
# 4  4  4  16  16
# 5  4  6  24  16
# 6  5  5  25  25
# 7  6  7  42  36
