# %%
print()
#MENU:
print("MENU")
print("1: Sumar")
#print("1: +")
print("2: -")
print("3: *")
print("4: Dividir (/)")
print()
#Ingreso datos
opcion=input("ingrese la opcion deseada del menu: ") # la opcion se guarda como cadena
#opcion=int(input("ingrese la opcion deseada del menu: ")) # la opcion se guarda como cadena
numero_uno=float(input('ingrese el primer numero de la operacion:')) # se guarda como flotante(numero real)
numero_dos=float(input('ingrese el segundo numero de la operacion:')) # se guarda como flotante(numero real)
#posibilidades para ejecutar calculadora:
#if opcion=='1':
# if opcion=='+':
# if opcion=='sumar':
if opcion==1:
   print("vamos a sumar(+) los dos valores ingresados:")
   print('la suma:',numero_uno+numero_dos)
if opcion=='2':
  print("vamos a restar(-) los dos valores ingresados:\n")
  resta=numero_uno-numero_dos
  #print("resultado="+str(resta)) # voy a concatenar dos cadenas(str1+str2: no suma sino que junta, str1str2)
  print("vamos(-) los dos valores ingresados:\n")
  resta=numero_uno-numero_dos
  #print("resultado="+str(resta))
