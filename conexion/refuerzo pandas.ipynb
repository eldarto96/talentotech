# %%
edad=28
nombre= "dario tobar"
nota=3.5
estado_est=True
print(f"el nombre del estudiante es {nombre}, su edad es {edad},la nota que obtuvo es {nota} y se encuentra en el estado {estado_est}")

# %%
lista=[1,"nuevo",3.5,True,1,"new"]
print(lista)
lista.append("nuevo")
print(lista)
lista.count("nuevo")
print(lista)
lista.index("new")
print(lista)

# %%
edad=int(input("ingrese su edad"))
print(edad)
if edad >=18:
    print("usted es mayor de edad")
else:
    print("usted es menor de edad")

# %%
alarma="no"
while alarma != "si":
 print("sono la alarma")
 alarma=input("¿sono la alarma? si/no")
print("despertate")
# Out:
# sono la alarma

# %%
import pandas as pd
diccionario={
    "nombre":["dario","michael","cardenas","martinez"],
    "edad":28
    "nota":3.5,
    "estado":True
}
print(diccionario)
df=pd.DataFrame([diccionario])
print(df)
