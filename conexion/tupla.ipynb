# %%
tupla=(1,2,"tres")
print(tupla)
print(tupla)
tupla.index(2)
#
# Out:
# (1, 2, 'tres')
# (1, 2, 'tres')
# 1

# %%
lista=[1,2,3]
print(lista)
lista[2]="tres"
print(lista)
# Out:
# [1, 2, 3]
# [1, 2, 'tres']

# %%
conjunto=set([1,2,3,3])
print(conjunto)
conjunto.add(4)
print(conjunto)
conjunto.remove(2)
print(conjunto)
# Out:
# {1, 2, 3}
# {1, 2, 3, 4}
# {1, 3, 4}

# %%
conjunto=set("hola mundo")
print(conjunto)
# Out:
# {'a', 'u', 'd', 'm', 'o', 'l', 'n', ' ', 'h'}

# %%
dic={"nombre":"dario",
     "edad":28,
     "correo":"dario@guachucal.com",
     "notas":[2.5,3.5,4.5]}
print(dic["notas"])
dic.keys()
dic.values()
dic.items()
# Out:
# [2.5, 3.5, 4.5]
# dict_items([('nombre', 'dario'), ('edad', 28), ('correo', 'dario@guachucal.com'), ('notas', [2.5, 3.5, 4.5])])

# %%
credenciales=("admin","123456")
usuario=input("ingrese su usuario:")
contraseña=input("ingrese su contraseña:")
if credenciales[0]==usuario and credenciales[1]==contraseña:
    print("bienvenido")
    estudiantes=[]
    cantidad=int(input( "ingrese la cantidad de estudiantes:"))

    for i in range(cantidad):
        nombre=input("ingrese el nombre del estudiante:")
        estudiantes.append(nombre)
    print(estudiantes)
else:
    print("usuario o contraseña incorrectos")
# Out:
# ingrese su usuario:admin
# ingrese su contraseña:123456
# bienvenido
# ingrese la cantidad de estudiantes:2
# ingrese el nombre del estudiante:c
# ingrese el nombre del estudiante:c
# ['c', 'c']

# %%
cantidad=int(input("ingrese la cantidad de notas:"))
for i in range(cantidad):
  nombre=input("ingrese el nombre del estudiante:")
  estudiantes.append(nombre)
print(estudiantes)

longitud=float(input("ingrese la longitud"))
latitud=float(input("ingrese la latitud"))
ubicacion=(longitud,latitud)
print(ubicacion)

correos=set()
cantidad=int(input("ingrese la cantidad de correos:"))
for i in range(cantidad):
  correo=input("ingrese el correo:")
  correos.add(correo)
  print(correos)

  datos_estudiantes={}
  datos_estudiantes["nombre"]=input("ingrese el nombre:")
  datos_estudiantes["edad"]=int(input("ingrese la edad:"))
  datos_estudiantes["correo"]=input("ingrese el correo:")

  #notas[]
  cantidad=int(input("ingrese la cantidad de notas:"))
  for i in range(cantidad):
    nota=float(input("ingrese la nota:"))
    notas.append(nota)
  datos_estudiantes["notas"]=notas
  print(datos_estudiantes)
else:
  print("usuario o contraseña incorrectos")
# Out:
# ['c', 'c', '4', '3', '5']
