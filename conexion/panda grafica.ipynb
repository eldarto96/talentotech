# %%
import pandas as pd

data={"nombre":["dann" , "michel" , "cardenas"],"edad":[25,45,40],"ciudad":["bogota" ,"cali", "medellin"]}
df=pd.DataFrame(data)

print(data)

print(df)

df
# Out:
# {'nombre': ['dann', 'michel', 'cardenas'], 'edad': [25, 45, 40], 'ciudad': ['bogota', 'cali', 'medellin']}
#      nombre  edad    ciudad
# 0      dann    25    bogota
# 1    michel    45      cali
# 2  cardenas    40  medellin
#      nombre  edad    ciudad
# 0      dann    25    bogota
# 1    michel    45      cali
# 2  cardenas    40  medellin
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['edad'].plot(kind='hist', bins=20, title='edad')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('nombre').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# ...

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Iris (1).csv")

df.head(20)
df.tail(15)
df.info()
df.describe()
df.plot(x='Species',y='PetalLengthCm', kind='bar')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# <Axes: xlabel='Species'>
