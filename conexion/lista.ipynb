# %%
#lista
lista=[1,"meza",25,3.14]
print (lista)

print(lista[2])

print(lista[-4])

lista.append("1")
print(lista)

lista.append("1")
lista.append("true")
lista.append("false")
lista.append("3.14")
lista.append("dario")
print(lista)

lista[9]="dato"
print(lista)

lista.count(3.14)

lista.index("dato")

lista[9]="datoo"
print(lista)

#listasort

listanumero=[3,5,8,15]
print(listanumero)

listanumero.sort()
print(listanumero)

listanumero.sort(reverse=True)
print(listanumero)

listanumero.reverse()
print(listanumero)

listanumero.append("orbes")
print(listanumero)
listanumero.append("jaime")
print(listanumero)

listanumero[5]="rita"
print[listanumero]
# Out:
# [1, 'meza', 25, 3.14]
# 25
# 1
# [1, 'meza', 25, 3.14, '1']
# [1, 'meza', 25, 3.14, '1', '1', 'true', 'false', '3.14', 'dario']
# [1, 'meza', 25, 3.14, '1', '1', 'true', 'false', '3.14', 'dato']
# [1, 'meza', 25, 3.14, '1', '1', 'true', 'false', '3.14', 'datoo']
# [3, 5, 8, 15]
# [3, 5, 8, 15]
# [15, 8, 5, 3]
# [3, 5, 8, 15]
# [3, 5, 8, 15, 'orbes']
# [3, 5, 8, 15, 'orbes', 'jaime']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2548155568.py in <cell line: 0>()
#      47
#      48 listanumero[5]="rita"
# ---> 49 print[listanumero]
#      50
#      51
#
# TypeError: 'builtin_function_or_method' object is not subscriptable
